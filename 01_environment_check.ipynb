# %% [markdown]
# # 01 — Environment Check
#
# ## Purpose
#
# This notebook verifies that the local development environment is ready for the AI E-Commerce Review Intelligence project.
#
# It checks that the core Python libraries can be imported, confirms that the Sentence Transformers model can be loaded, and validates that a sample text can be converted into an embedding vector.
#
# ## What this notebook does
#
# - Imports key project libraries such as `pandas` and `sentence-transformers`.
# - Loads the `all-MiniLM-L6-v2` embedding model.
# - Generates a test embedding from a sample sentence.
# - Confirms that the environment is ready for the next stages of data processing and semantic search.
#
# ## Expected output
#
# A successful run should print a confirmation message and return an embedding with shape:
#
# ```text
# (1, 384)

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer

# %%
print("✅ Environment is ready!")
model = SentenceTransformer("all-MiniLM-L6-v2")
emb = model.encode(["Helia's fresh start"])
print("Success! Embedding shape:", emb.shape)
# Out:
# ✅ Environment is ready!
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Success! Embedding shape: (1, 384)
